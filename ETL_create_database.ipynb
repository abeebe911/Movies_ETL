# %%
import json
import pandas as pd
import numpy as np

import re

from sqlalchemy import create_engine
import psycopg2

from config import db_password

import time

# %%
#  Add the clean movie function that takes in the argument, "movie".
def clean_movie(movie):
    movie = dict(movie) #create a non-destructive copy
    alt_titles = {}
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune–Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:
        if key in movie:
            alt_titles[key] = movie[key]
            movie.pop(key)
    if len(alt_titles) > 0:
        movie['alt_titles'] = alt_titles
    

    # merge column names
    def change_column_name(old_name, new_name):
        if old_name in movie:
            movie[new_name] = movie.pop(old_name)
    change_column_name('Adaptation by', 'Writer(s)')
    change_column_name('Country of origin', 'Country')
    change_column_name('Directed by', 'Director')
    change_column_name('Distributed by', 'Distributor')
    change_column_name('Edited by', 'Editor(s)')
    change_column_name('Length', 'Running time')
    change_column_name('Original release', 'Release date')
    change_column_name('Music by', 'Composer(s)')
    change_column_name('Produced by', 'Producer(s)')
    change_column_name('Producer', 'Producer(s)')
    change_column_name('Productioncompanies ', 'Production company(s)')
    change_column_name('Productioncompany ', 'Production company(s)')
    change_column_name('Released', 'Release Date')
    change_column_name('Release Date', 'Release date')
    change_column_name('Screen story by', 'Writer(s)')
    change_column_name('Screenplay by', 'Writer(s)')
    change_column_name('Story by', 'Writer(s)')
    change_column_name('Theme music composer', 'Composer(s)')
    change_column_name('Written by', 'Writer(s)')
    return movie

# %%
# 1 Add the function that takes in three arguments;
# Wikipedia data, Kaggle metadata, and MovieLens rating data (from Kaggle)


def extract_transform_load():
    # Read in the kaggle metadata and MovieLens ratings CSV files as Pandas DataFrames.
    kaggle_metadata = pd.read_csv(f'{file_dir}/movies_metadata.csv', low_memory = False)
    ratings = pd.read_csv(f'{file_dir}/ratings.csv')


    # Open and read the Wikipedia data JSON file.
    with open(f'{file_dir}/wikipedia.movies.json', mode='r') as file:
        wiki_movies_raw = json.load(file)
        
    wiki_movies_df = pd.DataFrame(wiki_movies_raw)
    
    
    # Write a list comprehension to filter out TV shows.
    wiki_movies = [movie for movie in wiki_movies_raw
               if ('Director' in movie or 'Directed by' in movie)
                   and 'imdb_link' in movie
                   and 'No. of episodes' not in movie]


    # Write a list comprehension to iterate through the cleaned wiki movies list
    # and call the clean_movie function on each movie.
    clean_movies = [clean_movie(movie) for movie in wiki_movies]

    # Read in the cleaned movies list from Step 4 as a DataFrame.
    wiki_movies_df = pd.DataFrame(clean_movies)
    sorted(wiki_movies_df.columns.tolist())

    # Write a try-except block to catch errors while extracting the IMDb ID using a regular expression string and
    #  dropping any imdb_id duplicates. If there is an error, capture and print the exception.
    try:
         wiki_movies_df['imdb_id'] = wiki_movies_df['imdb_link'].str.extract(r'(tt\d{7})')
         wiki_movies_df.drop_duplicates(subset='imdb_id', inplace=True)
        
    except Exception as e:
        print(e)
        
    #  Write a list comprehension to keep the columns that don't have null values from the wiki_movies_df DataFrame.
    wiki_columns_to_keep = [column for column in wiki_movies_df.columns if wiki_movies_df[column].isnull().sum() < len(wiki_movies_df) * 0.9]
    wiki_movies_df = wiki_movies_df[wiki_columns_to_keep]

    # Create a variable that will hold the non-null values from the “Box office” column.
    box_office = wiki_movies_df['Box office'].dropna()
    
    # Convert the box office data created in Step 8 to string values using the lambda and join functions.
    box_office = box_office.apply(lambda x: ' '.join(x) if type(x) == list else x)

    # Write a regular expression to match the six elements of "form_one" of the box office data.
    form_one = r'\$\s*\d+\.?\d*\s*[mb]illi?on'
    # Write a regular expression to match the three elements of "form_two" of the box office data.
    form_two = r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)'
    box_office = box_office.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)
    box_office.str.extract(f'({form_one}|{form_two})')

    # Add the parse_dollars function.
    def parse_dollars(s):
        # if s is not a string, return NaN
        if type(s) != str:
            return np.nan

        # if input is of the form $###.# million
        if re.match(r'\$\s*\d+\.?\d*\s*milli?on', s, flags=re.IGNORECASE):

            # remove dollar sign and " million"
            s = re.sub('\$|\s|[a-zA-Z]','', s)

            # convert to float and multiply by a million
            value = float(s) * 10**6

            # return value
            return value

        # if input is of the form $###.# billion
        elif re.match(r'\$\s*\d+\.?\d*\s*billi?on', s, flags=re.IGNORECASE):

            # remove dollar sign and " billion"
            s = re.sub('\$|\s|[a-zA-Z]','', s)

            # convert to float and multiply by a billion
            value = float(s) * 10**9

            # return value
            return value

        # if input is of the form $###,###,###
        elif re.match(r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)', s, flags=re.IGNORECASE):

            # remove dollar sign and commas
            s = re.sub('\$|,','', s)

            # convert to float
            value = float(s)

            # return value
            return value

        # otherwise, return NaN
        else:
            return np.nan
    
        
    # Clean the box office column in the wiki_movies_df DataFrame.
    wiki_movies_df['box_office'] = box_office.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)
    wiki_movies_df.drop('Box office', axis=1, inplace=True)
    
    # Clean the budget column in the wiki_movies_df DataFrame.
    budget = wiki_movies_df['Budget'].dropna()
    
    budget = budget.map(lambda x: ' '.join(x) if type(x) == list else x)
    
    budget = budget.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)
    
    budget.str.extract(f'({form_one}|{form_two})')
    
    budget = budget.str.replace(r'\[\d+\]\s*', '')
    
    matches_form_one = budget.str.contains(form_one, flags=re.IGNORECASE)
    matches_form_two = budget.str.contains(form_two, flags=re.IGNORECASE)
    
    budget[~matches_form_one & ~matches_form_two]
    
    wiki_movies_df['budget'] = budget.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)
    

    # Clean the release date column in the wiki_movies_df DataFrame.
    release_date = wiki_movies_df['Release date'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)
    
    date_form_one = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s[123]\d,\s\d{4}'
    date_form_two = r'\d{4}.[01]\d.[123]\d'
    date_form_three = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s\d{4}'
    date_form_four = r'\d{4}'

    release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})', flags=re.IGNORECASE)

    wiki_movies_df['release_date'] = pd.to_datetime(release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})')[0], infer_datetime_format=True)

    # Clean the running time column in the wiki_movies_df DataFrame.
    running_time = wiki_movies_df['Running time'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)

    running_time[running_time.str.contains(r'^\d*\s*m', flags=re.IGNORECASE) != True]

    running_time_extract = running_time.str.extract(r'(\d+)\s*ho?u?r?s?\s*(\d*)|(\d+)\s*m')
    
    running_time_extract = running_time_extract.apply(lambda col: pd.to_numeric(col, errors='coerce')).fillna(0)

    wiki_movies_df['running_time'] = running_time_extract.apply(lambda row: row[0]*60 + row[1] if row[2] == 0 else row[2], axis=1)

    wiki_movies_df.drop('Running time', axis=1, inplace=True)

     
    # 2. Clean the Kaggle metadata.
    # Remove bad data
    kaggle_metadata[~kaggle_metadata['adult'].isin(['True','False'])]
    
    # The following code will keep rows where the adult column is False, and then drop the adult column.
    kaggle_metadata = kaggle_metadata[kaggle_metadata['adult'] == 'False'].drop('adult',axis='columns')

    # This code creates the Boolean column we want.
    #kaggle_metadata['video'] == 'True'

    # Assign the boolean column we created avoce back to 'video'
    kaggle_metadata['video'] = kaggle_metadata['video'] == 'True'
    
    # creating these to numeric values
    kaggle_metadata['budget'] = kaggle_metadata['budget'].astype(int)
    kaggle_metadata['id'] = pd.to_numeric(kaggle_metadata['id'], errors='raise')
    kaggle_metadata['popularity'] = pd.to_numeric(kaggle_metadata['popularity'], errors='raise')
    
    # Converting it to date time format.
    kaggle_metadata['release_date'] = pd.to_datetime(kaggle_metadata['release_date'])

    
    # 3. Merged the two DataFrames into the movies DataFrame.
    movies_df = pd.merge(wiki_movies_df, kaggle_metadata, on='imdb_id', suffixes=['_wiki','_kaggle'])


    # 4. Drop unnecessary columns from the merged DataFrame.

    movies_df.drop(columns=['title_wiki','release_date_wiki','Language','Production company(s)'], inplace=True)


    # 5. Add in the function to fill in the missing Kaggle data.
    
    def fill_missing_kaggle_data(df, kaggle_column, wiki_column):
        df[kaggle_column] = df.apply(
            lambda row: row[wiki_column] if row[kaggle_column] == 0 else row[kaggle_column]
            , axis=1)
        df.drop(columns=wiki_column, inplace=True)

    # 6. Call the function in Step 5 with the DataFrame and columns as the arguments.
    fill_missing_kaggle_data(movies_df, 'runtime', 'running_time')
    fill_missing_kaggle_data(movies_df, 'budget_kaggle', 'budget_wiki')
    fill_missing_kaggle_data(movies_df, 'revenue', 'box_office')

    # 7. Filter the movies DataFrame for specific columns.
   
    movies_df = movies_df.loc[:, ['imdb_id','id','title_kaggle','original_title','tagline','belongs_to_collection','url','imdb_link',
                       'runtime','budget_kaggle','revenue','release_date_kaggle','popularity','vote_average','vote_count',
                       'genres','original_language','overview','spoken_languages','Country',
                       'production_companies','production_countries','Distributor',
                       'Producer(s)','Director','Starring','Cinematography','Editor(s)','Writer(s)','Composer(s)','Based on'
                      ]]
            

    # 8. Rename the columns in the movies DataFrame.
    movies_df.rename({'id':'kaggle_id',
                  'title_kaggle':'title',
                  'url':'wikipedia_url',
                  'budget_kaggle':'budget',
                  'release_date_kaggle':'release_date',
                  'Country':'country',
                  'Distributor':'distributor',
                  'Producer(s)':'producers',
                  'Director':'director',
                  'Starring':'starring',
                  'Cinematography':'cinematography',
                  'Editor(s)':'editors',
                  'Writer(s)':'writers',
                  'Composer(s)':'composers',
                  'Based on':'based_on'
                 }, axis='columns', inplace=True)
        

    # 9. Transform and merge the ratings DataFrame.
    rating_counts = ratings.groupby(['movieId','rating'], as_index=False).count()
        
    
    rating_counts = ratings.groupby(['movieId','rating'], as_index=False).count() \
                .rename({'userId':'count'}, axis=1)
        
    
    rating_counts = ratings.groupby(['movieId','rating'], as_index=False).count() \
                .rename({'userId':'count'}, axis=1) \
                .pivot(index='movieId',columns='rating', values='count')
        
    
    rating_counts.columns = ['rating_' + str(col) for col in rating_counts.columns]
    
    movies_with_ratings_df = pd.merge(movies_df, rating_counts, left_on='kaggle_id', right_index=True, how='left')

    db_string = f'postgres://postgres:{db_password}@127.0.0.1:5432/movie_data'
    engine = create_engine(db_string)
    movies_df.to_sql(name='movies', con=engine, if_exists='replace')
    
    #create a variable for the number of rows imported
    rows_imported = 0
    
    #get the start time from time.time()
    start_time = time.time()
    
    for data in pd.read_csv('ratings.csv', chunksize=50000):
        
        #print out the range of rows that are being imported
        print(f'importing rows {rows_imported} to {rows_imported + len(data)}...', end='')
        
        data.to_sql(name='ratings', con=engine, if_exists='append')
        
        #increment the number of rows imported by the size of 'data'
        rows_imported += len(data)
        
        #print that the rows have finished importing
        #add elapsed time to final print out
        print(f'Done. {time.time() - start_time} total seconds elapsed')

# %%
# 10. Create the path to your file directory and variables for the three files.
file_dir = '/Users/alexanderbeebe/Desktop/BootCamp/Modules/ETL/movies'
# The Wikipedia data
wiki_file = f'{file_dir}/wikipedia.movies.json'
# The Kaggle metadata
kaggle_file = f'{file_dir}/movies_metadata.csv'
# The MovieLens rating data.
ratings_file = f'{file_dir}/ratings.csv'

# %%
#11. Set the three variables equal to the function created in D!.
extract_transform_load()
# Out:
# importing rows 0 to 50000...Done. 4.697474956512451 total seconds elapsed
# importing rows 50000 to 100000...Done. 9.156030893325806 total seconds elapsed
# importing rows 100000 to 150000...Done. 13.86341404914856 total seconds elapsed
# importing rows 150000 to 200000...Done. 18.682199954986572 total seconds elapsed
# importing rows 200000 to 250000...Done. 23.948076963424683 total seconds elapsed
# importing rows 250000 to 300000...Done. 28.585047006607056 total seconds elapsed
# importing rows 300000 to 350000...Done. 33.2630078792572 total seconds elapsed
# importing rows 350000 to 400000...Done. 37.75130105018616 total seconds elapsed
# importing rows 400000 to 450000...Done. 42.19365191459656 total seconds elapsed
# importing rows 450000 to 500000...Done. 46.6326220035553 total seconds elapsed
# importing rows 500000 to 550000...Done. 51.028477907180786 total seconds elapsed
# importing rows 550000 to 600000...Done. 55.54644012451172 total seconds elapsed
# importing rows 600000 to 650000...Done. 60.158446073532104 total seconds elapsed
# importing rows 650000 to 700000...Done. 64.51037406921387 total seconds elapsed
# importing rows 700000 to 750000...Done. 68.82828307151794 total seconds elapsed
# importing rows 750000 to 800000...Done. 73.1166160106659 total seconds elapsed
# importing rows 800000 to 850000...Done. 77.33522295951843 total seconds elapsed
# importing rows 850000 to 900000...Done. 81.98252582550049 total seconds elapsed
# importing rows 900000 to 950000...Done. 86.78455591201782 total seconds elapsed
# importing rows 950000 to 1000000...Done. 91.38828110694885 total seconds elapsed
# importing rows 1000000 to 1050000...Done. 96.05522084236145 total seconds elapsed
# importing rows 1050000 to 1100000...Done. 100.32672595977783 total seconds elapsed
# importing rows 1100000 to 1150000...Done. 104.98909401893616 total seconds elapsed
# importing rows 1150000 to 1200000...Done. 109.47193384170532 total seconds elapsed
# importing rows 1200000 to 1250000...Done. 113.75434899330139 total seconds elapsed
# importing rows 1250000 to 1300000...Done. 118.07690691947937 total seconds elapsed
# importing rows 1300000 to 1350000...Done. 122.41561317443848 total seconds elapsed
# importing rows 1350000 to 1400000...Done. 126.53313183784485 total seconds elapsed
# importing rows 1400000 to 1450000...Done. 130.6988639831543 total seconds elapsed
# importing rows 1450000 to 1500000...Done. 134.89852094650269 total seconds elapsed
# importing rows 1500000 to 1550000...Done. 139.11970615386963 total seconds elapsed
# importing rows 1550000 to 1600000...Done. 143.35733604431152 total seconds elapsed
# importing rows 1600000 to 1650000...Done. 147.9811029434204 total seconds elapsed
# importing rows 1650000 to 1700000...Done. 152.82720494270325 total seconds elapsed
# importing rows 1700000 to 1750000...Done. 158.075021982193 total seconds elapsed
# importing rows 1750000 to 1800000...Done. 163.2025158405304 total seconds elapsed
# importing rows 1800000 to 1850000...Done. 168.74384093284607 total seconds elapsed
# importing rows 1850000 to 1900000...Done. 173.38023591041565 total seconds elapsed
# importing rows 1900000 to 1950000...Done. 178.11655116081238 total seconds elapsed
# importing rows 1950000 to 2000000...Done. 182.86855220794678 total seconds elapsed
# importing rows 2000000 to 2050000...Done. 188.01400804519653 total seconds elapsed
# importing rows 2050000 to 2100000...Done. 192.75855898857117 total seconds elapsed
# importing rows 2100000 to 2150000...Done. 199.5372929573059 total seconds elapsed
# importing rows 2150000 to 2200000...Done. 205.09218978881836 total seconds elapsed
# importing rows 2200000 to 2250000...Done. 210.04410314559937 total seconds elapsed
# importing rows 2250000 to 2300000...Done. 214.48786807060242 total seconds elapsed
# importing rows 2300000 to 2350000...Done. 218.60749101638794 total seconds elapsed
# importing rows 2350000 to 2400000...Done. 222.87810921669006 total seconds elapsed
# importing rows 2400000 to 2450000...Done. 227.0671877861023 total seconds elapsed
# importing rows 2450000 to 2500000...Done. 231.20456385612488 total seconds elapsed
# importing rows 2500000 to 2550000...Done. 235.42208194732666 total seconds elapsed
# importing rows 2550000 to 2600000...Done. 239.72588801383972 total seconds elapsed
# importing rows 2600000 to 2650000...Done. 244.06093502044678 total seconds elapsed
# importing rows 2650000 to 2700000...Done. 248.1972119808197 total seconds elapsed
# importing rows 2700000 to 2750000...Done. 252.75127792358398 total seconds elapsed
# importing rows 2750000 to 2800000...Done. 257.2322111129761 total seconds elapsed
# importing rows 2800000 to 2850000...Done. 261.47154808044434 total seconds elapsed
# importing rows 2850000 to 2900000...Done. 265.6654691696167 total seconds elapsed
# importing rows 2900000 to 2950000...Done. 269.8621621131897 total seconds elapsed
# importing rows 2950000 to 3000000...Done. 274.06803607940674 total seconds elapsed
# importing rows 3000000 to 3050000...Done. 278.18078994750977 total seconds elapsed
# importing rows 3050000 to 3100000...Done. 282.37468099594116 total seconds elapsed
# importing rows 3100000 to 3150000...Done. 286.536474943161 total seconds elapsed
# importing rows 3150000 to 3200000...Done. 290.6572940349579 total seconds elapsed
# importing rows 3200000 to 3250000...Done. 294.77763390541077 total seconds elapsed
# importing rows 3250000 to 3300000...Done. 298.98623514175415 total seconds elapsed
# importing rows 3300000 to 3350000...Done. 303.18767189979553 total seconds elapsed
# importing rows 3350000 to 3400000...Done. 307.27797198295593 total seconds elapsed
# importing rows 3400000 to 3450000...Done. 311.37281799316406 total seconds elapsed
# importing rows 3450000 to 3500000...Done. 315.49892807006836 total seconds elapsed
# importing rows 3500000 to 3550000...Done. 319.62445402145386 total seconds elapsed
# importing rows 3550000 to 3600000...Done. 323.92044401168823 total seconds elapsed
# importing rows 3600000 to 3650000...Done. 328.2678098678589 total seconds elapsed
# importing rows 3650000 to 3700000...Done. 332.4407579898834 total seconds elapsed
# importing rows 3700000 to 3750000...Done. 336.6664791107178 total seconds elapsed
# importing rows 3750000 to 3800000...Done. 340.9121460914612 total seconds elapsed
# importing rows 3800000 to 3850000...Done. 345.18431091308594 total seconds elapsed
# importing rows 3850000 to 3900000...Done. 349.35884404182434 total seconds elapsed
# importing rows 3900000 to 3950000...Done. 353.5713620185852 total seconds elapsed
# importing rows 3950000 to 4000000...Done. 357.7460060119629 total seconds elapsed
# importing rows 4000000 to 4050000...Done. 361.8909521102905 total seconds elapsed
# importing rows 4050000 to 4100000...Done. 366.0810389518738 total seconds elapsed
# importing rows 4100000 to 4150000...Done. 370.1689670085907 total seconds elapsed
# importing rows 4150000 to 4200000...Done. 374.3568949699402 total seconds elapsed
# importing rows 4200000 to 4250000...Done. 378.45567989349365 total seconds elapsed
# importing rows 4250000 to 4300000...Done. 382.67015504837036 total seconds elapsed
# importing rows 4300000 to 4350000...Done. 386.90090703964233 total seconds elapsed
# importing rows 4350000 to 4400000...Done. 391.01681303977966 total seconds elapsed
# importing rows 4400000 to 4450000...Done. 395.1582510471344 total seconds elapsed
# importing rows 4450000 to 4500000...Done. 399.2542350292206 total seconds elapsed
# importing rows 4500000 to 4550000...Done. 403.47368597984314 total seconds elapsed
# importing rows 4550000 to 4600000...Done. 407.6728630065918 total seconds elapsed
# importing rows 4600000 to 4650000...Done. 411.8527238368988 total seconds elapsed
# importing rows 4650000 to 4700000...Done. 415.9771749973297 total seconds elapsed
# importing rows 4700000 to 4750000...Done. 420.144140958786 total seconds elapsed
# importing rows 4750000 to 4800000...Done. 424.35188698768616 total seconds elapsed
# importing rows 4800000 to 4850000...Done. 428.52849197387695 total seconds elapsed
# importing rows 4850000 to 4900000...Done. 432.6729121208191 total seconds elapsed
# importing rows 4900000 to 4950000...Done. 437.089439868927 total seconds elapsed
# importing rows 4950000 to 5000000...Done. 441.776330947876 total seconds elapsed
# importing rows 5000000 to 5050000...Done. 446.16808795928955 total seconds elapsed
# importing rows 5050000 to 5100000...Done. 450.3321409225464 total seconds elapsed
# importing rows 5100000 to 5150000...Done. 454.5080280303955 total seconds elapsed
# importing rows 5150000 to 5200000...Done. 458.7145619392395 total seconds elapsed
# importing rows 5200000 to 5250000...Done. 462.8918261528015 total seconds elapsed
# importing rows 5250000 to 5300000...Done. 467.01354217529297 total seconds elapsed
# importing rows 5300000 to 5350000...Done. 471.1866159439087 total seconds elapsed
# importing rows 5350000 to 5400000...Done. 475.26418709754944 total seconds elapsed
# importing rows 5400000 to 5450000...Done. 479.4598219394684 total seconds elapsed
# importing rows 5450000 to 5500000...Done. 483.60894107818604 total seconds elapsed
# importing rows 5500000 to 5550000...Done. 487.77193808555603 total seconds elapsed
# importing rows 5550000 to 5600000...Done. 491.8990318775177 total seconds elapsed
# importing rows 5600000 to 5650000...Done. 496.03775095939636 total seconds elapsed
# importing rows 5650000 to 5700000...Done. 500.1277151107788 total seconds elapsed
# importing rows 5700000 to 5750000...Done. 504.40558195114136 total seconds elapsed
# importing rows 5750000 to 5800000...Done. 508.6033158302307 total seconds elapsed
# importing rows 5800000 to 5850000...Done. 512.7624318599701 total seconds elapsed
# importing rows 5850000 to 5900000...Done. 516.9131329059601 total seconds elapsed
# importing rows 5900000 to 5950000...Done. 521.0489909648895 total seconds elapsed
# importing rows 5950000 to 6000000...Done. 525.1902730464935 total seconds elapsed
# importing rows 6000000 to 6050000...Done. 529.3150010108948 total seconds elapsed
# importing rows 6050000 to 6100000...Done. 533.574501991272 total seconds elapsed
# importing rows 6100000 to 6150000...Done. 537.8352360725403 total seconds elapsed
# importing rows 6150000 to 6200000...Done. 541.9696679115295 total seconds elapsed
# importing rows 6200000 to 6250000...Done. 546.0374090671539 total seconds elapsed
# importing rows 6250000 to 6300000...Done. 550.1908588409424 total seconds elapsed
# importing rows 6300000 to 6350000...Done. 554.2914741039276 total seconds elapsed
# importing rows 6350000 to 6400000...Done. 558.4306190013885 total seconds elapsed
# importing rows 6400000 to 6450000...Done. 562.6238169670105 total seconds elapsed
# importing rows 6450000 to 6500000...Done. 566.7524788379669 total seconds elapsed
# importing rows 6500000 to 6550000...Done. 570.9147439002991 total seconds elapsed
# importing rows 6550000 to 6600000...Done. 575.0070650577545 total seconds elapsed
# importing rows 6600000 to 6650000...Done. 579.1113750934601 total seconds elapsed
# importing rows 6650000 to 6700000...Done. 583.2450239658356 total seconds elapsed
# importing rows 6700000 to 6750000...Done. 587.3444309234619 total seconds elapsed
# importing rows 6750000 to 6800000...Done. 591.4859728813171 total seconds elapsed
# importing rows 6800000 to 6850000...Done. 595.6528360843658 total seconds elapsed
# importing rows 6850000 to 6900000...Done. 599.7816739082336 total seconds elapsed
# importing rows 6900000 to 6950000...Done. 603.9279301166534 total seconds elapsed
# importing rows 6950000 to 7000000...Done. 608.0352659225464 total seconds elapsed
# importing rows 7000000 to 7050000...Done. 612.1790130138397 total seconds elapsed
# importing rows 7050000 to 7100000...Done. 616.2932729721069 total seconds elapsed
# importing rows 7100000 to 7150000...Done. 620.3614919185638 total seconds elapsed
# importing rows 7150000 to 7200000...Done. 624.5881671905518 total seconds elapsed
# importing rows 7200000 to 7250000...Done. 629.1536009311676 total seconds elapsed
# importing rows 7250000 to 7300000...Done. 634.3000519275665 total seconds elapsed
# importing rows 7300000 to 7350000...Done. 639.3658328056335 total seconds elapsed
# importing rows 7350000 to 7400000...Done. 644.1430990695953 total seconds elapsed
# importing rows 7400000 to 7450000...Done. 649.0919878482819 total seconds elapsed
# importing rows 7450000 to 7500000...Done. 653.9527978897095 total seconds elapsed
# importing rows 7500000 to 7550000...Done. 658.8284990787506 total seconds elapsed
# importing rows 7550000 to 7600000...Done. 663.6370851993561 total seconds elapsed
# importing rows 7600000 to 7650000...Done. 668.450756072998 total seconds elapsed
# importing rows 7650000 to 7700000...Done. 673.2152960300446 total seconds elapsed
# importing rows 7700000 to 7750000...Done. 678.1474640369415 total seconds elapsed
# importing rows 7750000 to 7800000...Done. 682.944727897644 total seconds elapsed
# importing rows 7800000 to 7850000...Done. 687.8221271038055 total seconds elapsed
# importing rows 7850000 to 7900000...Done. 692.6197700500488 total seconds elapsed
# importing rows 7900000 to 7950000...Done. 697.4240629673004 total seconds elapsed
# importing rows 7950000 to 8000000...Done. 702.2234230041504 total seconds elapsed
# importing rows 8000000 to 8050000...Done. 706.9515810012817 total seconds elapsed
# importing rows 8050000 to 8100000...Done. 711.7456958293915 total seconds elapsed
# importing rows 8100000 to 8150000...Done. 716.5555408000946 total seconds elapsed
# importing rows 8150000 to 8200000...Done. 721.3064150810242 total seconds elapsed
# importing rows 8200000 to 8250000...Done. 726.0857620239258 total seconds elapsed
# importing rows 8250000 to 8300000...Done. 730.8691980838776 total seconds elapsed
# importing rows 8300000 to 8350000...Done. 735.693213224411 total seconds elapsed
# importing rows 8350000 to 8400000...Done. 740.5212359428406 total seconds elapsed
# importing rows 8400000 to 8450000...Done. 745.4927861690521 total seconds elapsed
# importing rows 8450000 to 8500000...Done. 750.3611569404602 total seconds elapsed
# importing rows 8500000 to 8550000...Done. 755.1631588935852 total seconds elapsed
# importing rows 8550000 to 8600000...Done. 759.9451591968536 total seconds elapsed
# importing rows 8600000 to 8650000...Done. 764.8365988731384 total seconds elapsed
# importing rows 8650000 to 8700000...Done. 769.6340398788452 total seconds elapsed
# importing rows 8700000 to 8750000...Done. 774.574845790863 total seconds elapsed
# importing rows 8750000 to 8800000...Done. 779.5356340408325 total seconds elapsed
# importing rows 8800000 to 8850000...Done. 784.5205271244049 total seconds elapsed
# importing rows 8850000 to 8900000...Done. 789.3107750415802 total seconds elapsed
# importing rows 8900000 to 8950000...Done. 794.1339509487152 total seconds elapsed
# importing rows 8950000 to 9000000...Done. 798.9693820476532 total seconds elapsed
# importing rows 9000000 to 9050000...Done. 803.853569984436 total seconds elapsed
# importing rows 9050000 to 9100000...Done. 808.6986520290375 total seconds elapsed
# importing rows 9100000 to 9150000...Done. 813.4914929866791 total seconds elapsed
# importing rows 9150000 to 9200000...Done. 818.3094379901886 total seconds elapsed
# importing rows 9200000 to 9250000...Done. 823.1620359420776 total seconds elapsed
# importing rows 9250000 to 9300000...Done. 828.0048251152039 total seconds elapsed
# importing rows 9300000 to 9350000...Done. 832.7802648544312 total seconds elapsed
# importing rows 9350000 to 9400000...Done. 837.7238690853119 total seconds elapsed
# importing rows 9400000 to 9450000...Done. 842.5580971240997 total seconds elapsed
# importing rows 9450000 to 9500000...Done. 847.346519947052 total seconds elapsed
# importing rows 9500000 to 9550000...Done. 852.2596180438995 total seconds elapsed
# importing rows 9550000 to 9600000...Done. 857.3405060768127 total seconds elapsed
# importing rows 9600000 to 9650000...Done. 862.3819749355316 total seconds elapsed
# importing rows 9650000 to 9700000...Done. 867.4585890769958 total seconds elapsed
# importing rows 9700000 to 9750000...Done. 872.4679169654846 total seconds elapsed
# importing rows 9750000 to 9800000...Done. 877.4567000865936 total seconds elapsed
# importing rows 9800000 to 9850000...Done. 882.5103631019592 total seconds elapsed
# importing rows 9850000 to 9900000...Done. 887.4123208522797 total seconds elapsed
# importing rows 9900000 to 9950000...Done. 892.3641140460968 total seconds elapsed
# importing rows 9950000 to 10000000...Done. 897.2829949855804 total seconds elapsed
# importing rows 10000000 to 10050000...Done. 902.1726939678192 total seconds elapsed
# importing rows 10050000 to 10100000...Done. 907.0804569721222 total seconds elapsed
# importing rows 10100000 to 10150000...Done. 911.988123178482 total seconds elapsed
# importing rows 10150000 to 10200000...Done. 916.8899178504944 total seconds elapsed
# importing rows 10200000 to 10250000...Done. 921.7713439464569 total seconds elapsed
# importing rows 10250000 to 10300000...Done. 926.9786329269409 total seconds elapsed
# importing rows 10300000 to 10350000...Done. 931.9885458946228 total seconds elapsed
# importing rows 10350000 to 10400000...Done. 936.8354358673096 total seconds elapsed
# importing rows 10400000 to 10450000...Done. 941.7791478633881 total seconds elapsed
# importing rows 10450000 to 10500000...Done. 946.7616848945618 total seconds elapsed
# importing rows 10500000 to 10550000...Done. 951.7631809711456 total seconds elapsed
# importing rows 10550000 to 10600000...Done. 956.7076690196991 total seconds elapsed
# importing rows 10600000 to 10650000...Done. 961.6290199756622 total seconds elapsed
# importing rows 10650000 to 10700000...Done. 966.5824859142303 total seconds elapsed
# importing rows 10700000 to 10750000...Done. 971.5335850715637 total seconds elapsed
# importing rows 10750000 to 10800000...Done. 976.4873490333557 total seconds elapsed
# importing rows 10800000 to 10850000...Done. 981.5909841060638 total seconds elapsed
# importing rows 10850000 to 10900000...Done. 986.5676729679108 total seconds elapsed
# importing rows 10900000 to 10950000...Done. 991.6173350811005 total seconds elapsed
# importing rows 10950000 to 11000000...Done. 996.5419991016388 total seconds elapsed
# importing rows 11000000 to 11050000...Done. 1001.5315392017365 total seconds elapsed
# importing rows 11050000 to 11100000...Done. 1006.4386348724365 total seconds elapsed
# importing rows 11100000 to 11150000...Done. 1011.407262802124 total seconds elapsed
# importing rows 11150000 to 11200000...Done. 1016.3558549880981 total seconds elapsed
# importing rows 11200000 to 11250000...Done. 1021.4226558208466 total seconds elapsed
# importing rows 11250000 to 11300000...Done. 1026.309522151947 total seconds elapsed
# importing rows 11300000 to 11350000...Done. 1031.244742155075 total seconds elapsed
# importing rows 11350000 to 11400000...Done. 1036.2933328151703 total seconds elapsed
# importing rows 11400000 to 11450000...Done. 1041.2994821071625 total seconds elapsed
# importing rows 11450000 to 11500000...Done. 1046.3257100582123 total seconds elapsed
# importing rows 11500000 to 11550000...Done. 1051.3285648822784 total seconds elapsed
# importing rows 11550000 to 11600000...Done. 1056.3420751094818 total seconds elapsed
# importing rows 11600000 to 11650000...Done. 1061.3260660171509 total seconds elapsed
# importing rows 11650000 to 11700000...Done. 1066.3097188472748 total seconds elapsed
# importing rows 11700000 to 11750000...Done. 1071.2766630649567 total seconds elapsed
# importing rows 11750000 to 11800000...Done. 1076.1141810417175 total seconds elapsed
# importing rows 11800000 to 11850000...Done. 1080.9909989833832 total seconds elapsed
# importing rows 11850000 to 11900000...Done. 1085.9525799751282 total seconds elapsed
# importing rows 11900000 to 11950000...Done. 1090.9357550144196 total seconds elapsed
# importing rows 11950000 to 12000000...Done. 1095.8563559055328 total seconds elapsed
# importing rows 12000000 to 12050000...Done. 1100.864907026291 total seconds elapsed
# importing rows 12050000 to 12100000...Done. 1105.9019119739532 total seconds elapsed
# importing rows 12100000 to 12150000...Done. 1111.011502981186 total seconds elapsed
# importing rows 12150000 to 12200000...Done. 1115.9942049980164 total seconds elapsed
# importing rows 12200000 to 12250000...Done. 1121.0351359844208 total seconds elapsed
# importing rows 12250000 to 12300000...Done. 1126.127457857132 total seconds elapsed
# importing rows 12300000 to 12350000...Done. 1131.1749370098114 total seconds elapsed
# importing rows 12350000 to 12400000...Done. 1136.144061088562 total seconds elapsed
# importing rows 12400000 to 12450000...Done. 1141.2456722259521 total seconds elapsed
# importing rows 12450000 to 12500000...Done. 1146.479199886322 total seconds elapsed
# importing rows 12500000 to 12550000...Done. 1151.5613191127777 total seconds elapsed
# importing rows 12550000 to 12600000...Done. 1156.6135330200195 total seconds elapsed
# importing rows 12600000 to 12650000...Done. 1161.8280408382416 total seconds elapsed
# importing rows 12650000 to 12700000...Done. 1167.0225269794464 total seconds elapsed
# importing rows 12700000 to 12750000...Done. 1172.0731980800629 total seconds elapsed
# importing rows 12750000 to 12800000...Done. 1177.0238499641418 total seconds elapsed
# importing rows 12800000 to 12850000...Done. 1181.8650929927826 total seconds elapsed
# importing rows 12850000 to 12900000...Done. 1186.74902176857 total seconds elapsed
# importing rows 12900000 to 12950000...Done. 1191.630696773529 total seconds elapsed
# importing rows 12950000 to 13000000...Done. 1196.498363018036 total seconds elapsed
# importing rows 13000000 to 13050000...Done. 1201.4508020877838 total seconds elapsed
# importing rows 13050000 to 13100000...Done. 1206.298830986023 total seconds elapsed
# importing rows 13100000 to 13150000...Done. 1211.2470300197601 total seconds elapsed
# importing rows 13150000 to 13200000...Done. 1216.1244909763336 total seconds elapsed
# importing rows 13200000 to 13250000...Done. 1221.0494661331177 total seconds elapsed
# importing rows 13250000 to 13300000...Done. 1225.9976828098297 total seconds elapsed
# importing rows 13300000 to 13350000...Done. 1230.939467906952 total seconds elapsed
# importing rows 13350000 to 13400000...Done. 1235.7962548732758 total seconds elapsed
# importing rows 13400000 to 13450000...Done. 1240.644108057022 total seconds elapsed
# importing rows 13450000 to 13500000...Done. 1245.540489912033 total seconds elapsed
# importing rows 13500000 to 13550000...Done. 1250.5595710277557 total seconds elapsed
# importing rows 13550000 to 13600000...Done. 1255.4677081108093 total seconds elapsed
# importing rows 13600000 to 13650000...Done. 1260.3686408996582 total seconds elapsed
# importing rows 13650000 to 13700000...Done. 1265.231971025467 total seconds elapsed
# importing rows 13700000 to 13750000...Done. 1270.1018450260162 total seconds elapsed
# importing rows 13750000 to 13800000...Done. 1274.9825439453125 total seconds elapsed
# importing rows 13800000 to 13850000...Done. 1279.8163318634033 total seconds elapsed
# importing rows 13850000 to 13900000...Done. 1284.6995570659637 total seconds elapsed
# importing rows 13900000 to 13950000...Done. 1289.6175808906555 total seconds elapsed
# importing rows 13950000 to 14000000...Done. 1294.5122740268707 total seconds elapsed
# importing rows 14000000 to 14050000...Done. 1299.3183670043945 total seconds elapsed
# importing rows 14050000 to 14100000...Done. 1304.2727122306824 total seconds elapsed
# importing rows 14100000 to 14150000...Done. 1309.1274240016937 total seconds elapsed
# importing rows 14150000 to 14200000...Done. 1314.0065109729767 total seconds elapsed
# importing rows 14200000 to 14250000...Done. 1319.00261592865 total seconds elapsed
# importing rows 14250000 to 14300000...Done. 1323.8669109344482 total seconds elapsed
# importing rows 14300000 to 14350000...Done. 1328.735759973526 total seconds elapsed
# importing rows 14350000 to 14400000...Done. 1333.5893568992615 total seconds elapsed
# importing rows 14400000 to 14450000...Done. 1338.456797838211 total seconds elapsed
# importing rows 14450000 to 14500000...Done. 1343.6509637832642 total seconds elapsed
# importing rows 14500000 to 14550000...Done. 1348.8919970989227 total seconds elapsed
# importing rows 14550000 to 14600000...Done. 1353.9314711093903 total seconds elapsed
# importing rows 14600000 to 14650000...Done. 1358.0220341682434 total seconds elapsed
# importing rows 14650000 to 14700000...Done. 1362.2709710597992 total seconds elapsed
# importing rows 14700000 to 14750000...Done. 1366.476840019226 total seconds elapsed
# importing rows 14750000 to 14800000...Done. 1370.674301147461 total seconds elapsed
# importing rows 14800000 to 14850000...Done. 1374.7805800437927 total seconds elapsed
# importing rows 14850000 to 14900000...Done. 1378.958477973938 total seconds elapsed
# importing rows 14900000 to 14950000...Done. 1383.110081911087 total seconds elapsed
# importing rows 14950000 to 15000000...Done. 1387.2288689613342 total seconds elapsed
# importing rows 15000000 to 15050000...Done. 1391.4118399620056 total seconds elapsed
# importing rows 15050000 to 15100000...Done. 1395.5207657814026 total seconds elapsed
# importing rows 15100000 to 15150000...Done. 1399.5997149944305 total seconds elapsed
# importing rows 15150000 to 15200000...Done. 1403.816782951355 total seconds elapsed
# importing rows 15200000 to 15250000...Done. 1408.051547050476 total seconds elapsed
# importing rows 15250000 to 15300000...Done. 1412.1620509624481 total seconds elapsed
# importing rows 15300000 to 15350000...Done. 1416.2777540683746 total seconds elapsed
# importing rows 15350000 to 15400000...Done. 1420.3883218765259 total seconds elapsed
# importing rows 15400000 to 15450000...Done. 1424.6164059638977 total seconds elapsed
# importing rows 15450000 to 15500000...Done. 1428.7756049633026 total seconds elapsed
# importing rows 15500000 to 15550000...Done. 1432.9341778755188 total seconds elapsed
# importing rows 15550000 to 15600000...Done. 1437.1344738006592 total seconds elapsed
# importing rows 15600000 to 15650000...Done. 1441.3005759716034 total seconds elapsed
# importing rows 15650000 to 15700000...Done. 1445.457200050354 total seconds elapsed
# importing rows 15700000 to 15750000...Done. 1449.5736219882965 total seconds elapsed
# importing rows 15750000 to 15800000...Done. 1453.7407810688019 total seconds elapsed
# importing rows 15800000 to 15850000...Done. 1457.8873000144958 total seconds elapsed
# importing rows 15850000 to 15900000...Done. 1462.0603530406952 total seconds elapsed
# importing rows 15900000 to 15950000...Done. 1466.2053639888763 total seconds elapsed
# importing rows 15950000 to 16000000...Done. 1470.3583478927612 total seconds elapsed
# importing rows 16000000 to 16050000...Done. 1474.4705970287323 total seconds elapsed
# importing rows 16050000 to 16100000...Done. 1478.5797970294952 total seconds elapsed
# importing rows 16100000 to 16150000...Done. 1482.721498966217 total seconds elapsed
# importing rows 16150000 to 16200000...Done. 1486.8652551174164 total seconds elapsed
# importing rows 16200000 to 16250000...Done. 1491.0152838230133 total seconds elapsed
# importing rows 16250000 to 16300000...Done. 1495.1123178005219 total seconds elapsed
# importing rows 16300000 to 16350000...Done. 1499.171079158783 total seconds elapsed
# importing rows 16350000 to 16400000...Done. 1503.3254499435425 total seconds elapsed
# importing rows 16400000 to 16450000...Done. 1507.4247410297394 total seconds elapsed
# importing rows 16450000 to 16500000...Done. 1511.5733909606934 total seconds elapsed
# importing rows 16500000 to 16550000...Done. 1515.6898968219757 total seconds elapsed
# importing rows 16550000 to 16600000...Done. 1519.7713170051575 total seconds elapsed
# importing rows 16600000 to 16650000...Done. 1523.9810018539429 total seconds elapsed
# importing rows 16650000 to 16700000...Done. 1528.1669521331787 total seconds elapsed
# importing rows 16700000 to 16750000...Done. 1532.3544080257416 total seconds elapsed
# importing rows 16750000 to 16800000...Done. 1536.470708847046 total seconds elapsed
# importing rows 16800000 to 16850000...Done. 1540.6168539524078 total seconds elapsed
# importing rows 16850000 to 16900000...Done. 1544.7585489749908 total seconds elapsed
# importing rows 16900000 to 16950000...Done. 1548.9508309364319 total seconds elapsed
# importing rows 16950000 to 17000000...Done. 1553.0719769001007 total seconds elapsed
# importing rows 17000000 to 17050000...Done. 1557.214525938034 total seconds elapsed
# importing rows 17050000 to 17100000...Done. 1561.334331035614 total seconds elapsed
# importing rows 17100000 to 17150000...Done. 1565.5183320045471 total seconds elapsed
# importing rows 17150000 to 17200000...Done. 1569.6415338516235 total seconds elapsed
# importing rows 17200000 to 17250000...Done. 1573.7668330669403 total seconds elapsed
# importing rows 17250000 to 17300000...Done. 1577.9317080974579 total seconds elapsed
# importing rows 17300000 to 17350000...Done. 1582.1797649860382 total seconds elapsed
# importing rows 17350000 to 17400000...Done. 1586.2986040115356 total seconds elapsed
# importing rows 17400000 to 17450000...Done. 1590.4276268482208 total seconds elapsed
# importing rows 17450000 to 17500000...Done. 1594.6275618076324 total seconds elapsed
# importing rows 17500000 to 17550000...Done. 1598.7623920440674 total seconds elapsed
# importing rows 17550000 to 17600000...Done. 1602.9393599033356 total seconds elapsed
# importing rows 17600000 to 17650000...Done. 1607.0196089744568 total seconds elapsed
# importing rows 17650000 to 17700000...Done. 1611.1889879703522 total seconds elapsed
# importing rows 17700000 to 17750000...Done. 1615.3386118412018 total seconds elapsed
# importing rows 17750000 to 17800000...Done. 1619.4930579662323 total seconds elapsed
# importing rows 17800000 to 17850000...Done. 1623.6520779132843 total seconds elapsed
# importing rows 17850000 to 17900000...Done. 1627.788362979889 total seconds elapsed
# importing rows 17900000 to 17950000...Done. 1631.8676059246063 total seconds elapsed
# importing rows 17950000 to 18000000...Done. 1636.05109500885 total seconds elapsed
# importing rows 18000000 to 18050000...Done. 1640.2587010860443 total seconds elapsed
# importing rows 18050000 to 18100000...Done. 1644.4735379219055 total seconds elapsed
# importing rows 18100000 to 18150000...Done. 1648.670235157013 total seconds elapsed
# importing rows 18150000 to 18200000...Done. 1652.7784938812256 total seconds elapsed
# importing rows 18200000 to 18250000...Done. 1656.9374809265137 total seconds elapsed
# importing rows 18250000 to 18300000...Done. 1661.0296339988708 total seconds elapsed
# importing rows 18300000 to 18350000...Done. 1665.2065289020538 total seconds elapsed
# importing rows 18350000 to 18400000...Done. 1669.3067569732666 total seconds elapsed
# importing rows 18400000 to 18450000...Done. 1673.5137190818787 total seconds elapsed
# importing rows 18450000 to 18500000...Done. 1677.690337896347 total seconds elapsed
# importing rows 18500000 to 18550000...Done. 1681.8354499340057 total seconds elapsed
# importing rows 18550000 to 18600000...Done. 1685.999154806137 total seconds elapsed
# importing rows 18600000 to 18650000...Done. 1690.1567368507385 total seconds elapsed
# importing rows 18650000 to 18700000...Done. 1694.2686669826508 total seconds elapsed
# importing rows 18700000 to 18750000...Done. 1698.3017151355743 total seconds elapsed
# importing rows 18750000 to 18800000...Done. 1702.5406408309937 total seconds elapsed
# importing rows 18800000 to 18850000...Done. 1706.7046329975128 total seconds elapsed
# importing rows 18850000 to 18900000...Done. 1710.8273839950562 total seconds elapsed
# importing rows 18900000 to 18950000...Done. 1714.971361875534 total seconds elapsed
# importing rows 18950000 to 19000000...Done. 1719.105926990509 total seconds elapsed
# importing rows 19000000 to 19050000...Done. 1723.2840869426727 total seconds elapsed
# importing rows 19050000 to 19100000...Done. 1727.4121069908142 total seconds elapsed
# importing rows 19100000 to 19150000...Done. 1731.5503950119019 total seconds elapsed
# importing rows 19150000 to 19200000...Done. 1735.6459710597992 total seconds elapsed
# importing rows 19200000 to 19250000...Done. 1739.8317458629608 total seconds elapsed
# importing rows 19250000 to 19300000...Done. 1743.968985080719 total seconds elapsed
# importing rows 19300000 to 19350000...Done. 1748.1393671035767 total seconds elapsed
# importing rows 19350000 to 19400000...Done. 1752.276990890503 total seconds elapsed
# importing rows 19400000 to 19450000...Done. 1756.4207541942596 total seconds elapsed
# importing rows 19450000 to 19500000...Done. 1760.4950351715088 total seconds elapsed
# importing rows 19500000 to 19550000...Done. 1764.7410399913788 total seconds elapsed
# importing rows 19550000 to 19600000...Done. 1768.8243408203125 total seconds elapsed
# importing rows 19600000 to 19650000...Done. 1773.0470051765442 total seconds elapsed
# importing rows 19650000 to 19700000...Done. 1777.1606738567352 total seconds elapsed
# importing rows 19700000 to 19750000...Done. 1781.2931628227234 total seconds elapsed
# importing rows 19750000 to 19800000...Done. 1785.4151678085327 total seconds elapsed
# importing rows 19800000 to 19850000...Done. 1789.5502219200134 total seconds elapsed
# importing rows 19850000 to 19900000...Done. 1793.6659619808197 total seconds elapsed
# importing rows 19900000 to 19950000...Done. 1797.8080229759216 total seconds elapsed
# importing rows 19950000 to 20000000...Done. 1801.9170501232147 total seconds elapsed
# importing rows 20000000 to 20050000...Done. 1806.0056188106537 total seconds elapsed
# importing rows 20050000 to 20100000...Done. 1810.1614859104156 total seconds elapsed
# importing rows 20100000 to 20150000...Done. 1814.3119640350342 total seconds elapsed
# importing rows 20150000 to 20200000...Done. 1818.397488117218 total seconds elapsed
# importing rows 20200000 to 20250000...Done. 1822.5797049999237 total seconds elapsed
# importing rows 20250000 to 20300000...Done. 1826.7899029254913 total seconds elapsed
# importing rows 20300000 to 20350000...Done. 1830.9280171394348 total seconds elapsed
# importing rows 20350000 to 20400000...Done. 1835.0587589740753 total seconds elapsed
# importing rows 20400000 to 20450000...Done. 1839.1216549873352 total seconds elapsed
# importing rows 20450000 to 20500000...Done. 1843.3203928470612 total seconds elapsed
# importing rows 20500000 to 20550000...Done. 1847.4947459697723 total seconds elapsed
# importing rows 20550000 to 20600000...Done. 1851.570501089096 total seconds elapsed
# importing rows 20600000 to 20650000...Done. 1855.6400039196014 total seconds elapsed
# importing rows 20650000 to 20700000...Done. 1859.8083791732788 total seconds elapsed
# importing rows 20700000 to 20750000...Done. 1863.9428369998932 total seconds elapsed
# importing rows 20750000 to 20800000...Done. 1868.0738790035248 total seconds elapsed
# importing rows 20800000 to 20850000...Done. 1872.281818151474 total seconds elapsed
# importing rows 20850000 to 20900000...Done. 1876.4042899608612 total seconds elapsed
# importing rows 20900000 to 20950000...Done. 1880.5676970481873 total seconds elapsed
# importing rows 20950000 to 21000000...Done. 1884.7223558425903 total seconds elapsed
# importing rows 21000000 to 21050000...Done. 1888.9668390750885 total seconds elapsed
# importing rows 21050000 to 21100000...Done. 1893.0653190612793 total seconds elapsed
# importing rows 21100000 to 21150000...Done. 1897.202987909317 total seconds elapsed
# importing rows 21150000 to 21200000...Done. 1901.359941959381 total seconds elapsed
# importing rows 21200000 to 21250000...Done. 1905.535348892212 total seconds elapsed
# importing rows 21250000 to 21300000...Done. 1909.6589438915253 total seconds elapsed
# importing rows 21300000 to 21350000...Done. 1913.7560081481934 total seconds elapsed
# importing rows 21350000 to 21400000...Done. 1917.9591751098633 total seconds elapsed
# importing rows 21400000 to 21450000...Done. 1922.1800391674042 total seconds elapsed
# importing rows 21450000 to 21500000...Done. 1926.279872894287 total seconds elapsed
# importing rows 21500000 to 21550000...Done. 1930.370882987976 total seconds elapsed
# importing rows 21550000 to 21600000...Done. 1934.5568330287933 total seconds elapsed
# importing rows 21600000 to 21650000...Done. 1938.7381958961487 total seconds elapsed
# importing rows 21650000 to 21700000...Done. 1942.9638199806213 total seconds elapsed
# importing rows 21700000 to 21750000...Done. 1947.0924468040466 total seconds elapsed
# importing rows 21750000 to 21800000...Done. 1951.2856299877167 total seconds elapsed
# importing rows 21800000 to 21850000...Done. 1955.4536440372467 total seconds elapsed
# importing rows 21850000 to 21900000...Done. 1959.5764269828796 total seconds elapsed
# importing rows 21900000 to 21950000...Done. 1963.7990429401398 total seconds elapsed
# importing rows 21950000 to 22000000...Done. 1967.9443991184235 total seconds elapsed
# importing rows 22000000 to 22050000...Done. 1972.1005411148071 total seconds elapsed
# importing rows 22050000 to 22100000...Done. 1976.25132894516 total seconds elapsed
# importing rows 22100000 to 22150000...Done. 1980.4286279678345 total seconds elapsed
# importing rows 22150000 to 22200000...Done. 1984.5664989948273 total seconds elapsed
# importing rows 22200000 to 22250000...Done. 1988.7405858039856 total seconds elapsed
# importing rows 22250000 to 22300000...Done. 1992.8656978607178 total seconds elapsed
# importing rows 22300000 to 22350000...Done. 1997.0123209953308 total seconds elapsed
# importing rows 22350000 to 22400000...Done. 2001.0759830474854 total seconds elapsed
# importing rows 22400000 to 22450000...Done. 2005.3054671287537 total seconds elapsed
# importing rows 22450000 to 22500000...Done. 2009.4832129478455 total seconds elapsed
# importing rows 22500000 to 22550000...Done. 2013.7273588180542 total seconds elapsed
# importing rows 22550000 to 22600000...Done. 2017.8771829605103 total seconds elapsed
# importing rows 22600000 to 22650000...Done. 2022.1193780899048 total seconds elapsed
# importing rows 22650000 to 22700000...Done. 2026.2605130672455 total seconds elapsed
# importing rows 22700000 to 22750000...Done. 2030.4270911216736 total seconds elapsed
# importing rows 22750000 to 22800000...Done. 2034.5626320838928 total seconds elapsed
# importing rows 22800000 to 22850000...Done. 2038.6658868789673 total seconds elapsed
# importing rows 22850000 to 22900000...Done. 2042.8533899784088 total seconds elapsed
# importing rows 22900000 to 22950000...Done. 2046.9846789836884 total seconds elapsed
# importing rows 22950000 to 23000000...Done. 2051.0972530841827 total seconds elapsed
# importing rows 23000000 to 23050000...Done. 2055.2077910900116 total seconds elapsed
# importing rows 23050000 to 23100000...Done. 2059.3112180233 total seconds elapsed
# importing rows 23100000 to 23150000...Done. 2063.5893170833588 total seconds elapsed
# importing rows 23150000 to 23200000...Done. 2067.7262029647827 total seconds elapsed
# importing rows 23200000 to 23250000...Done. 2071.8127431869507 total seconds elapsed
# importing rows 23250000 to 23300000...Done. 2075.908061981201 total seconds elapsed
# importing rows 23300000 to 23350000...Done. 2079.9879310131073 total seconds elapsed
# importing rows 23350000 to 23400000...Done. 2084.195116996765 total seconds elapsed
# importing rows 23400000 to 23450000...Done. 2088.412311077118 total seconds elapsed
# importing rows 23450000 to 23500000...Done. 2092.5334918498993 total seconds elapsed
# importing rows 23500000 to 23550000...Done. 2096.730451107025 total seconds elapsed
# importing rows 23550000 to 23600000...Done. 2100.804127931595 total seconds elapsed
# importing rows 23600000 to 23650000...Done. 2105.0228550434113 total seconds elapsed
# importing rows 23650000 to 23700000...Done. 2109.1360218524933 total seconds elapsed
# importing rows 23700000 to 23750000...Done. 2113.2818999290466 total seconds elapsed
# importing rows 23750000 to 23800000...Done. 2117.448662042618 total seconds elapsed
# importing rows 23800000 to 23850000...Done. 2121.6824510097504 total seconds elapsed
# importing rows 23850000 to 23900000...Done. 2125.8508920669556 total seconds elapsed
# importing rows 23900000 to 23950000...Done. 2130.0087039470673 total seconds elapsed
# importing rows 23950000 to 24000000...Done. 2134.2059519290924 total seconds elapsed
# importing rows 24000000 to 24050000...Done. 2138.3644919395447 total seconds elapsed
# importing rows 24050000 to 24100000...Done. 2142.5646739006042 total seconds elapsed
# importing rows 24100000 to 24150000...Done. 2146.6794290542603 total seconds elapsed
# importing rows 24150000 to 24200000...Done. 2150.884521961212 total seconds elapsed
# importing rows 24200000 to 24250000...Done. 2155.081460952759 total seconds elapsed
# importing rows 24250000 to 24300000...Done. 2159.2632269859314 total seconds elapsed
# importing rows 24300000 to 24350000...Done. 2163.431240081787 total seconds elapsed
# importing rows 24350000 to 24400000...Done. 2167.5811398029327 total seconds elapsed
# importing rows 24400000 to 24450000...Done. 2171.7268600463867 total seconds elapsed
# importing rows 24450000 to 24500000...Done. 2175.9129550457 total seconds elapsed
# importing rows 24500000 to 24550000...Done. 2180.0719249248505 total seconds elapsed
# importing rows 24550000 to 24600000...Done. 2184.3264660835266 total seconds elapsed
# importing rows 24600000 to 24650000...Done. 2188.590560913086 total seconds elapsed
# importing rows 24650000 to 24700000...Done. 2192.7250940799713 total seconds elapsed
# importing rows 24700000 to 24750000...Done. 2196.8627619743347 total seconds elapsed
# importing rows 24750000 to 24800000...Done. 2201.0173301696777 total seconds elapsed
# importing rows 24800000 to 24850000...Done. 2205.204202890396 total seconds elapsed
# importing rows 24850000 to 24900000...Done. 2209.381650209427 total seconds elapsed
# importing rows 24900000 to 24950000...Done. 2213.5619461536407 total seconds elapsed
# importing rows 24950000 to 25000000...Done. 2217.789937019348 total seconds elapsed
# importing rows 25000000 to 25050000...Done. 2221.945149898529 total seconds elapsed
# importing rows 25050000 to 25100000...Done. 2226.1164779663086 total seconds elapsed
# importing rows 25100000 to 25150000...Done. 2230.311304807663 total seconds elapsed
# importing rows 25150000 to 25200000...Done. 2234.4763419628143 total seconds elapsed
# importing rows 25200000 to 25250000...Done. 2238.602478981018 total seconds elapsed
# importing rows 25250000 to 25300000...Done. 2242.7838718891144 total seconds elapsed
# importing rows 25300000 to 25350000...Done. 2246.9965670108795 total seconds elapsed
# importing rows 25350000 to 25400000...Done. 2251.126363992691 total seconds elapsed
# importing rows 25400000 to 25450000...Done. 2255.2542288303375 total seconds elapsed
# importing rows 25450000 to 25500000...Done. 2259.415184020996 total seconds elapsed
# importing rows 25500000 to 25550000...Done. 2263.585932970047 total seconds elapsed
# importing rows 25550000 to 25600000...Done. 2267.7011671066284 total seconds elapsed
# importing rows 25600000 to 25650000...Done. 2271.8352868556976 total seconds elapsed
# importing rows 25650000 to 25700000...Done. 2275.942661046982 total seconds elapsed
# importing rows 25700000 to 25750000...Done. 2280.058860063553 total seconds elapsed
# importing rows 25750000 to 25800000...Done. 2284.209981203079 total seconds elapsed
# importing rows 25800000 to 25850000...Done. 2288.3248438835144 total seconds elapsed
# importing rows 25850000 to 25900000...Done. 2292.4411602020264 total seconds elapsed
# importing rows 25900000 to 25950000...Done. 2296.6393599510193 total seconds elapsed
# importing rows 25950000 to 26000000...Done. 2300.6866459846497 total seconds elapsed
# importing rows 26000000 to 26024289...Done. 2302.7865331172943 total seconds elapsed
